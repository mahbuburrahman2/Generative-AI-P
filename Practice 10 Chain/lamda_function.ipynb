# %%
import numbers

from sympy.abc import lamda


def square(number):
    return number * number
square(4)
# Out:
# 16

# %% [markdown]
# lambda arguments : expression

# %%
var = lambda number: number * number
square(2)
# Out:
# 4

# %%
def is_adult(age):
    return age >= 18
is_adult(3)
# Out:
# False

# %%
is_adult =lambda age : age >= 18
is_adult(19)
# Out:
# True

# %%
x = {"question": "What is 2 + 3"}

# %%
def check_question(X):
    for ch in x ["question"]:
        if ch.isdigit():
            return True
    return None

# %%
check_question(x)
# Out:
# True

# %%
def check_question(x):
    return [ch.isdigit() for ch in x['question']]

# %%
check_question(x)
# Out:
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True]

# %%
lambda x : any(ch.isdigit() for ch in x['question'])
# Out:
# <function __main__.<lambda>(x)>

# %%
check_question(x)
# Out:
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True]
